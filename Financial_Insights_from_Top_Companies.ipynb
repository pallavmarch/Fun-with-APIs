# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavmarch/Fun-with-APIs-Pokemon-and-Wizards/blob/main/Financial_Insights_from_Top_Companies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf


tickers = ['AAPL', 'MSFT', 'TSLA', 'GOOGL','NVDA','NFLX','WMT','DIS']


for symbol in tickers:
    print("=" * 80)
    print(f"Financial Summary for: {symbol}")
    print("=" * 80)

    stock = yf.Ticker(symbol)
    info = stock.info

    print(f"Company: {info.get('longName')}")
    print(f"Sector: {info.get('sector')}")
    print(f"Country: {info.get('country')}")
    print(f"Market Cap: ${info.get('marketCap')}")
    print(f"Current Price: ${info.get('currentPrice')}")
    print("\n")

    print("Quarterly Balance Sheet:")
    display(balance_sheet)
    print("\n")

    print("Quarterly Income Statement:")
    display(income_statement)
    print("\n")

    print("Quarterly Cash Flow:")
    display(cash_flow)

    print("\n" + "-" * 100 + "\n\n")
# Out:
# ...
# Financial Summary for: AAPL
# ...
# Company: Apple Inc.
# Sector: Technology
# Country: United States
# Market Cap: $3189540126720
# Current Price: $213.55
#
#
# Quarterly Balance Sheet:
#            Treasury Shares Number Ordinary Shares Number Share Issued  \
# 2025-03-31                    1.0            219715850.0  219715851.0
# 2024-12-31                    1.0            208484810.0  208484811.0
# 2024-09-30                    1.0            208484210.0  208484211.0
# 2024-06-30                    1.0            208484210.0  208484211.0
# 2024-03-31                    1.0            205374610.0  205374611.0
# 2023-12-31                    NaN                    NaN          NaN
#
#              Net Debt Total Debt Tangible Book Value Invested Capital  \
# 2025-03-31  1067524.0  1213253.0          -3918778.0       -2705525.0
# 2024-12-31  3555275.0  3597442.0          -6369273.0       -2771831.0
# 2024-09-30  3383178.0  3390044.0          -6001303.0       -2611259.0
# ...
